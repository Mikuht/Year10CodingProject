# %%
#Setup

import json
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams.update({'figure.autolayout': True})
plt.style.use('fivethirtyeight')

# %%
#Function Def

def sortdic(diction):
    diction = dict(sorted(diction.items(), key=lambda item: item[1],reverse=True))
    return diction

def percentage(x, pos):
    s = '{:1.0f}%'.format(x)
    return s

def get_key(val, my_dict):
    for key, value in my_dict.items():
         if val == value:
             return key
 
    return "key doesn't exist"

def usage_percentage(level):
    for a in level:
    # print()
    # print(a)
        for b in level[a]:
            usage[a][b] = level[a][b] / own[b]
            # print(characters[b] + ":" + str(usage[a][b]))

# %%
#Load json File
#Create counting list format

characters = json.load(open("characters.json"))
abyss = json.load(open("v2.0-star36.json"))
charList = {}
for i in characters:
    charList[i] = 0
print(charList)
# Out:
# {'10000002': 0, '10000003': 0, '10000005': 0, '10000006': 0, '10000007': 0, '10000014': 0, '10000015': 0, '10000016': 0, '10000020': 0, '10000021': 0, '10000022': 0, '10000023': 0, '10000024': 0, '10000025': 0, '10000026': 0, '10000027': 0, '10000029': 0, '10000030': 0, '10000031': 0, '10000032': 0, '10000033': 0, '10000034': 0, '10000035': 0, '10000036': 0, '10000037': 0, '10000038': 0, '10000039': 0, '10000041': 0, '10000042': 0, '10000043': 0, '10000044': 0, '10000045': 0, '10000046': 0, '10000047': 0, '10000048': 0, '10000051': 0}

# %%
#Count Ownership data from json
#Count Usage data from json
#Calculate Average Level of Each Character
#Calculate Average Constellation of Each Character
#Count Team Usage data from json

level9team = {"f9_1_a" : {}, "f9_1_b" : {}, "f9_2_a" : {},"f9_2_b" : {},"f9_3_a" : {},"f9_3_b" : {}}
level10team = {"f10_1_a" : {}, "f10_1_b" : {}, "f10_2_a" : {},"f10_2_b" : {},"f10_3_a" : {},"f10_3_b" : {}}
level11team = {"f11_1_a" : {}, "f11_1_b" : {}, "f11_2_a" : {},"f11_2_b" : {},"f11_3_a" : {},"f11_3_b" : {}}
level12team = {"f12_1_a" : {}, "f12_1_b" : {}, "f12_2_a" : {},"f12_2_b" : {},"f12_3_a" : {},"f12_3_b" : {}}
teams = {}
own = charList.copy()
averageLevel = charList.copy()
averageConstellation = charList.copy()
level9 = {"f9_1_a" : charList.copy(), "f9_1_b" : charList.copy(), "f9_2_a" : charList.copy(),"f9_2_b" : charList.copy(),"f9_3_a" : charList.copy(),"f9_3_b" : charList.copy()}
level10 = {"f10_1_a" : charList.copy(), "f10_1_b" : charList.copy(), "f10_2_a" : charList.copy(),"f10_2_b" : charList.copy(),"f10_3_a" : charList.copy(),"f10_3_b" : charList.copy()}
level11 = {"f11_1_a" : charList.copy(), "f11_1_b" : charList.copy(), "f11_2_a" : charList.copy(),"f11_2_b" : charList.copy(),"f11_3_a" : charList.copy(),"f11_3_b" : charList.copy()}
level12 = {"f12_1_a" : charList.copy(), "f12_1_b" : charList.copy(), "f12_2_a" : charList.copy(),"f12_2_b" : charList.copy(),"f12_3_a" : charList.copy(),"f12_3_b" : charList.copy()}
for i in abyss:
    for j in i:
        if j == "roles":
            for x in i[j]:
                own[str(x)] += 1
        if j == "roles_detail":
            for x in i[j]:
                averageLevel[str(x)] += i[j][x]["level"]
                averageConstellation[str(x)] += i[j][x]["constellations"]
        if j in level9:
            temp = i[j]
            if str(temp) in level9team[j]:
                level9team[j][str(temp)] += 1
            else:
                if not temp in teams.values():
                    teams[str(temp)] = temp
                level9team[j][str(temp)] = 1
            for x in i[j]:
                level9[j][str(x)] += 1
        if j in level10:
            temp = i[j]
            if str(temp) in level10team[j]:
                level10team[j][str(temp)] += 1
            else:
                if not temp in teams.values():
                    teams[str(temp)] = temp
                level10team[j][str(temp)] = 1
            for x in i[j]:
                level10[j][str(x)] += 1
        if j in level11:
            temp = i[j]
            if str(temp) in level11team[j]:
                level11team[j][str(temp)] += 1
            else:
                if not temp in teams.values():
                    teams[str(temp)] = temp
                level11team[j][str(temp)] = 1
            for x in i[j]:
                level11[j][str(x)] += 1
        if j in level12:
            temp = i[j]
            if str(temp) in level12team[j]:
                level12team[j][str(temp)] += 1
            else:
                if not temp in teams.values():
                    teams[str(temp)] = temp
                level12team[j][str(temp)] = 1
            for x in i[j]:
                level12[j][str(x)] += 1
for i in averageConstellation:
    averageConstellation[i] /= own[i]
    # print(characters[i] + ":" + str(averageConstellation[i]))
for i in averageLevel:
    averageLevel[i] /= own[i]
    # print(characters[i] + ":" + str(averageLevel[i]))
for i in level9team:
    level9team[i] = sortdic(level9team[i])
    # for j in level9team[i]:
    #     print(j + ": " + str(level9team[i][str(j)]))
    # print()
for i in level10team:
    level10team[i] = sortdic(level10team[i])
for i in level11team:
    level11team[i] = sortdic(level11team[i])
for i in level12team:
    level12team[i] = sortdic(level12team[i])

# %%
# Transform Ownership count into percentage
# Showing Counting Datas with character names

# print("ownership")
ownRate = charList.copy()
for a in own:
    # print(characters[a] + ":" + str(own[a]))
    ownRate[a] = own[a] / 1000.00
# print()
# # ownRate = sortdic(ownRate)
# for a in ownRate:
#     print(characters[a] + ":" + str(ownRate[a]))
# for a in level9:
#     print()
#     print(a)
#     for b in level9[a]:
#         print(characters[b] + ":" + str(level9[a][b]))
# for a in level10:
#     print()
#     print(a)
#     for b in level10[a]:
#         print(characters[b] + ":" + str(level10[a][b]))
# for a in level11:
#     print()
#     print(a)
#     for b in level11[a]:
#         print(characters[b] + ":" + str(level11[a][b]))
# for a in level12:
#     print()
#     print(a)
#     for b in level12[a]:
#         print(characters[b] + ":" + str(level12[a][b]))

# %%
#Find the level that each character was most used in
#Create list of using count of characters in each level

mostUsed = {}
useCount = {}
for i in characters:
    mostUsed[i] = ""
    useCount[i] = [0,0,0,0]
for c in characters:
    for i in level9:
        useCount[c][0] += level9[i][c]
    for i in level10:
        useCount[c][1] += level10[i][c]
    for i in level11:
        useCount[c][2] += level11[i][c]
    for i in level12:
        useCount[c][3] += level12[i][c]
    # print(characters[c])
    # for i in useCount[c]:
    #     print(i)
    match np.argmax(useCount[c]):
        case 0:
            mostUsed[c] = "level 9"
        case 1:
            mostUsed[c] = "level 10"
        case 2:
            mostUsed[c] = "level 11"
        case 3:
            mostUsed[c] = "level 12"

# for i in mostUsed:
#     print(characters[i] + ": "+  str(mostUsed[i]))

# %%
#Transform Usage count into percentage

usage = {"f9_1_a" : charList.copy(), "f9_1_b" : charList.copy(), "f9_2_a" : charList.copy(),"f9_2_b" : charList.copy(),"f9_3_a" : charList.copy(),"f9_3_b" : charList.copy(), "f10_1_a" : charList.copy(), "f10_1_b" : charList.copy(), "f10_2_a" : charList.copy(),"f10_2_b" : charList.copy(),"f10_3_a" : charList.copy(),"f10_3_b" : charList.copy(), "f11_1_a" : charList.copy(), "f11_1_b" : charList.copy(), "f11_2_a" : charList.copy(),"f11_2_b" : charList.copy(),"f11_3_a" : charList.copy(),"f11_3_b" : charList.copy(), "f12_1_a" : charList.copy(), "f12_1_b" : charList.copy(), "f12_2_a" : charList.copy(),"f12_2_b" : charList.copy(),"f12_3_a" : charList.copy(),"f12_3_b" : charList.copy()}
usage_percentage(level9)
usage_percentage(level10)
usage_percentage(level11)
usage_percentage(level12)

# %%
#Calculate total (average) Usage

totalUsage = charList.copy()
for a in usage:
    for b in usage[a]:
        totalUsage[b] += usage[a][b]

for i in totalUsage:
    totalUsage[i] /= 12
    # print(characters[i] + ":" + str(totalUsage[i]))

# totalUsage = sortdic(totalUsage)

# for i in totalUsage:
#     print(characters[i] + ":" + str(totalUsage[i]))

# %%
#Output Chart - Rate of Owning and Using

sortOwn = {}
for i in sortdic(ownRate):
    sortOwn[i] = ownRate[i] * 100
sortUse = {}
for i in sortOwn:
    sortUse[i] = totalUsage[i] * 100

useName = []
for i in sortUse:
    useName.append(characters[i])
ownName = []
for i in sortOwn:
    ownName.append(characters[i])

y=np.arange(len(ownName))
width = 0.4
fig, charG = plt.subplots(figsize=(12,20))
charG.set(xlim=[0,100.3], ylabel = "Characters", title = "Rate of Owning & Using Characters", yticks = y, yticklabels = ownName)
ownBar = charG.barh(y - width/2, list(sortOwn.values()), width, label = "owning rate")
useBar = charG.barh(y + width/2, list(sortUse.values()), width, label = "using rate")
charG.legend()
charG.bar_label(ownBar, padding = 3)
charG.bar_label(useBar, padding = 3)
plt.suptitle("(sorted by owning rate)")

charG.xaxis.set_major_formatter(percentage)
plt.show()

# %%
#Output

for l in level9team:
    print(l)
    count = 0
    for i in level9team[l]:
        count+=1
        for c in teams[i]:
            print(characters[str(c)],end=" ")
        print(":"+" "+"{:.1%}".format(level9team[l][i]/1000))
        for c in teams[i]:
            print(c,end=" ")
        print()
        if count == 3: break
for l in level10team:
    print(l)
    count = 0
    for i in level10team[l]:
        count+=1
        for c in teams[i]:
            print(characters[str(c)],end=" ")
        print(":"+" "+"{:.1%}".format(level10team[l][i]/1000))
        for c in teams[i]:
            print(c,end=" ")
        print()
        if count == 3: break
for l in level11team:
    print(l)
    count = 0
    for i in level11team[l]:
        count+=1
        for c in teams[i]:
            print(characters[str(c)],end=" ")
        print(":"+" "+"{:.1%}".format(level11team[l][i]/1000))
        for c in teams[i]:
            print(c,end=" ")
        print()
        if count == 3: break
for l in level12team:
    print(l)
    count = 0
    for i in level12team[l]:
        count+=1
        for c in teams[i]:
            print(characters[str(c)],end=" ")
        print(":"+" "+"{:.1%}".format(level12team[l][i]/1000))
        for c in teams[i]:
            print(c,end=" ")
        print()
        if count == 3: break
# Out:
# 10000002 10000022 10000039 10000041
# f12_3_b
# Xingqiu Zhongli Albedo Hutao : 2.8%
# 10000025 10000030 10000038 10000046
# Ayaka Venti Diona Mona : 2.7%
# 10000002 10000022 10000039 10000041
# Xingqiu Zhongli Hutao Kazuha : 2.6%
# 10000025 10000030 10000046 10000047

# %%
#Output Individual Character Data

for c in characters:
    print(characters[c]+":")
    print("Average Level: "+ "{:.1f}".format(averageLevel[c]))
    print("Average Constellation: "+ "{:.1f}".format(averageConstellation[c]))
    print("Owning Rate: "+ "{:.1%}".format(ownRate[c]))
    print("Using Rate: "+ "{:.2%}".format(totalUsage[c]))
    if(totalUsage[c] == 0):
        print("Most Being Used in: "+ "N/A")
        print()
        continue
    print("Most Being Used in: "+ mostUsed[c])
    labels = "level 9", "level 10", "level 11", "level 12"
    sizes = [useCount[c][0], useCount[c][1], useCount[c][2], useCount[c][3]]
    fig2, each = plt.subplots()
    each.pie(sizes, labels = labels, autopct = "%1.2f%%", shadow = True, startangle = 90)
    plt.title("Usage Proportion Among Levels:")
    plt.suptitle(characters[c],y=0.9)
    each.axis("equal")
    plt.show()
    print()
# Out:
# Ayaka:
# Average Level: 80.0
# Average Constellation: 0.6
# Owning Rate: 68.0%
# Using Rate: 65.32%
# Most Being Used in: level 12
# Jean:
# Average Level: 75.2
# Average Constellation: 1.1
# Owning Rate: 78.0%
# Using Rate: 26.51%
# Most Being Used in: level 9
# TravelerM:
# Average Level: 63.7
# Average Constellation: 3.2
# Owning Rate: 23.2%
# Using Rate: 11.35%
# Most Being Used in: level 12
# Lisa:
# Average Level: 39.7
# Average Constellation: 1.5
# Owning Rate: 100.0%
# Using Rate: 0.17%
# Most Being Used in: level 12
# TravelerF:
# Average Level: 64.0
# Average Constellation: 3.3
# Owning Rate: 76.8%
# Using Rate: 0.00%
# Most Being Used in: N/A
#
# Barbara:
# Average Level: 57.8
# Average Constellation: 5.0
# Owning Rate: 100.0%
# Using Rate: 8.52%
# Most Being Used in: level 11
# Kaeya:
# Average Level: 41.2
# Average Constellation: 1.5
# Owning Rate: 100.0%
# Using Rate: 1.39%
# Most Being Used in: level 10
# Diluc:
# Average Level: 74.0
# Average Constellation: 1.1
# Owning Rate: 78.8%
# Using Rate: 22.47%
# Most Being Used in: level 11
# Razor:
# Average Level: 49.1
# Average Constellation: 4.3
# Owning Rate: 99.4%
# Using Rate: 0.54%
# Most Being Used in: level 9
# Amber:
# Average Level: 38.7
# Average Constellation: 1.5
# Owning Rate: 100.0%
# Using Rate: 0.20%
# Most Being Used in: level 11
# Venti:
# Average Level: 80.5
# Average Constellation: 0.4
# Owning Rate: 88.3%
# Using Rate: 76.96%
# Most Being Used in: level 9
# Xiangling:
# Average Level: 68.9
# Average Constellation: 5.2
# Owning Rate: 100.0%
# Using Rate: 27.47%
# Most Being Used in: level 12
# Beidou:
# Average Level: 52.3
# Average Constellation: 4.8
# Owning Rate: 100.0%
# Using Rate: 3.43%
# Most Being Used in: level 12
# Xingqiu:
# Average Level: 75.9
# Average Constellation: 5.2
# Owning Rate: 99.9%
# Using Rate: 69.02%
# Most Being Used in: level 11
# Xiao:
# Average Level: 82.4
# Average Constellation: 0.5
# Owning Rate: 51.6%
# Using Rate: 44.77%
# Most Being Used in: level 9
# Ningguang:
# Average Level: 60.1
# Average Constellation: 4.4
# Owning Rate: 99.2%
# Using Rate: 7.02%
# Most Being Used in: level 12
# Klee:
# Average Level: 79.2
# Average Constellation: 0.6
# Owning Rate: 57.8%
# Using Rate: 23.18%
# Most Being Used in: level 11
# Zhongli:
# Average Level: 83.1
# Average Constellation: 0.7
# Owning Rate: 93.6%
# Using Rate: 89.23%
# Most Being Used in: level 12
# Fischl:
# Average Level: 66.7
# Average Constellation: 4.9
# Owning Rate: 99.6%
# Using Rate: 11.06%
# Most Being Used in: level 12
# Bennett:
# Average Level: 77.0
# Average Constellation: 4.1
# Owning Rate: 99.6%
# Using Rate: 69.53%
# Most Being Used in: level 12
# Tartaglia:
# Average Level: 76.7
# Average Constellation: 0.6
# Owning Rate: 49.8%
# Using Rate: 29.64%
# Most Being Used in: level 11
# Noelle:
# Average Level: 55.1
# Average Constellation: 5.2
# Owning Rate: 100.0%
# Using Rate: 4.38%
# Most Being Used in: level 9
# Qiqi:
# Average Level: 62.3
# Average Constellation: 1.2
# Owning Rate: 76.2%
# Using Rate: 7.79%
# Most Being Used in: level 9
# Chongyun:
# Average Level: 57.2
# Average Constellation: 4.6
# Owning Rate: 99.7%
# Using Rate: 10.61%
# Most Being Used in: level 10
# Ganyu:
# Average Level: 84.2
# Average Constellation: 0.7
# Owning Rate: 68.5%
# Using Rate: 75.72%
# Most Being Used in: level 10
# Albedo:
# Average Level: 75.6
# Average Constellation: 0.4
# Owning Rate: 30.0%
# Using Rate: 30.03%
# Most Being Used in: level 12
# Diona:
# Average Level: 67.7
# Average Constellation: 4.7
# Owning Rate: 100.0%
# Using Rate: 49.32%
# Most Being Used in: level 10
# Mona:
# Average Level: 73.6
# Average Constellation: 1.1
# Owning Rate: 76.5%
# Using Rate: 56.47%
# Most Being Used in: level 11
# Keqing:
# Average Level: 71.7
# Average Constellation: 1.2
# Owning Rate: 82.2%
# Using Rate: 6.19%
# Most Being Used in: level 9
# Sucrose:
# Average Level: 63.7
# Average Constellation: 4.3
# Owning Rate: 99.7%
# Using Rate: 16.98%
# Most Being Used in: level 9
# Xinyan:
# Average Level: 31.9
# Average Constellation: 4.0
# Owning Rate: 97.9%
# Using Rate: 0.26%
# Most Being Used in: level 12
# Rosaria:
# Average Level: 36.9
# Average Constellation: 2.5
# Owning Rate: 92.2%
# Using Rate: 2.78%
# Most Being Used in: level 12
# Hutao:
# Average Level: 82.9
# Average Constellation: 0.7
# Owning Rate: 59.9%
# Using Rate: 69.30%
# Most Being Used in: level 11
# Kazuha:
# Average Level: 81.1
# Average Constellation: 0.6
# Owning Rate: 62.0%
# Using Rate: 84.52%
# Most Being Used in: level 9
# Yanfei:
# Average Level: 34.6
# Average Constellation: 3.0
# Owning Rate: 94.7%
# Using Rate: 1.28%
# Most Being Used in: level 11
# Eula:
# Average Level: 80.8
# Average Constellation: 0.7
# Owning Rate: 49.9%
# Using Rate: 27.59%
# Most Being Used in: level 12
